# %% [markdown]
# # TruncatedSVD benchmarks using the lobpcg solver
#
# https://github.com/scikit-learn/scikit-learn/pull/12319
#
# These benchmarks were run on a 4-core Xeon Skylake CPU on Linux with 64 GB RAM.

# %%
from sklearn.decomposition import TruncatedSVD

# %%
import numpy as np
import pandas as pd  # pandas is required for this notebook by the neurtu package
import scipy.sparse

from neurtu import delayed, timeit

# %%
rng = np.random.RandomState(43)

# %% [markdown]
# ## Sparse data

# %%
def make_sparse(n_samples, n_features, density):
    rng1 = np.random.RandomState(42)
    rng2 = np.random.RandomState(43)

    nnz = int(n_samples*n_features*density)
    row = rng1.randint(n_samples, size=nnz)
    cols = rng2.randint(n_features, size=nnz)

    data = rng1.rand(nnz)
    
    X = scipy.sparse.coo_matrix((data, (row, cols)), shape=(n_samples, n_features))
    return X.asformat('csr')


def benchmark_sparse():
    for n_features in [10000, 100000]:
        for n_samples in [5000, 20000, 100000]:
            for density in [0.01, 0.0001]:
                if density == 0.01 and n_features > 50000:
                    continue
                #X = scipy.sparse.rand(n_samples, n_features, density=density, random_state=42)
                X = make_sparse(n_samples, n_features, density)
                for n_components in [2, 20, 100]:
                    for algorithm in ['randomized', 'lobpcg']:
                        params = {'n_components': n_components,
                                  "n_samples": n_samples,
                                  "n_features": n_features,
                                  "nnz": X.nnz,
                                  "density": density,
                                  "algorithm": algorithm,
                                 }
                        
                        yield delayed(TruncatedSVD, tags=params)(n_components=n_components, algorithm=algorithm).fit_transform(X)

# %%
df = timeit(benchmark_sparse(), repeat=3).wall_time
# Out:
# 162it [04:35,  5.65s/it]

# %% [markdown]
# Below is the wall_time in seconds (faster solver is highlighted in green),

# %%
def highlight_best(s):
    is_max = s == s.min()
    return ['background-color: #206b3c80' if v else '' for v in is_max]

df['mean'].unstack().round(2).style.apply(highlight_best, axis=1)
# Out:
# <style  type="text/css" >
#     #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow0_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow1_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow2_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow3_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow4_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow5_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow5_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow6_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow7_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow8_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow9_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow10_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow11_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow12_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow13_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow14_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow15_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow16_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow17_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow18_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow19_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow20_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow21_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow22_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow23_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow24_col0 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow25_col1 {
#             background-color:  #206b3c80;
#         }    #T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow26_col1 {
#             background-color:  #206b3c80;
#         }</style><table id="T_a851e144_62a6_11e9_bf2d_5bf4718a25ef" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="index_name level0" >algorithm</th>        <th class="col_heading level0 col0" >lobpcg</th>        <th class="col_heading level0 col1" >randomized</th>    </tr>    <tr>        <th class="index_name level0" >n_components</th>        <th class="index_name level1" >n_samples</th>        <th class="index_name level2" >n_features</th>        <th class="index_name level3" >nnz</th>        <th class="index_name level4" >density</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel0_row0" class="row_heading level0 row0" rowspan=9>2</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel1_row0" class="row_heading level1 row0" rowspan=3>5000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel2_row0" class="row_heading level2 row0" rowspan=2>10000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel3_row0" class="row_heading level3 row0" >5000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel4_row0" class="row_heading level4 row0" >0.0001</th>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow0_col0" class="data row0 col0" >0.03</td>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow0_col1" class="data row0 col1" >0.02</td>
#             </tr>
#             <tr>
#                                                 <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel3_row1" class="row_heading level3 row1" >497497</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel4_row1" class="row_heading level4 row1" >0.01</th>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow1_col0" class="data row1 col0" >0.1</td>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow1_col1" class="data row1 col1" >0.07</td>
#             </tr>
#             <tr>
#                                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel2_row2" class="row_heading level2 row2" >100000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel3_row2" class="row_heading level3 row2" >49998</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel4_row2" class="row_heading level4 row2" >0.0001</th>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow2_col0" class="data row2 col0" >0.08</td>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow2_col1" class="data row2 col1" >0.12</td>
#             </tr>
#             <tr>
#                                 <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel1_row3" class="row_heading level1 row3" rowspan=3>20000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel2_row3" class="row_heading level2 row3" rowspan=2>10000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel3_row3" class="row_heading level3 row3" >19999</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel4_row3" class="row_heading level4 row3" >0.0001</th>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow3_col0" class="data row3 col0" >0.06</td>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow3_col1" class="data row3 col1" >0.04</td>
#             </tr>
#             <tr>
#                                                 <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel3_row4" class="row_heading level3 row4" >1990158</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel4_row4" class="row_heading level4 row4" >0.01</th>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow4_col0" class="data row4 col0" >0.33</td>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow4_col1" class="data row4 col1" >0.27</td>
#             </tr>
#             <tr>
#                                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel2_row5" class="row_heading level2 row5" >100000</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel3_row5" class="row_heading level3 row5" >199989</th>
#                         <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel4_row5" class="row_heading level4 row5" >0.0001</th>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow5_col0" class="data row5 col0" >0.2</td>
#                         <td id="T_a851e144_62a6_11e9_bf2d_5bf4718a25efrow5_col1" class="data row5 col1" >0.2</td>
#             </tr>
#             <tr>
#                                 <th id="T_a851e144_62a6_11e9_bf2d_5bf4718a25eflevel1_row6" cla

# %% [markdown]
# ## Dense data

# %%
def benchmark_dense():
    for n_features in [50, 500, 1000, 5000]:
        for n_samples in [5000, 20000, 50000, 100000, 1000000]:
                if n_features * n_samples > (5000*100000):
                    continue
                rng = np.random.RandomState(42)
                X = rng.randn(n_samples, n_features)
                for n_components in [2, 20, 100]:
                    if n_components >= n_features:
                        continue
                    for algorithm in ['randomized', 'lobpcg']:
                        params = {'n_components': n_components,
                                  "n_samples": n_samples,
                                  "n_features": n_features,
                                  "algorithm": algorithm,
                                 }
                        
                        yield delayed(TruncatedSVD, tags=params)(n_components=n_components, algorithm=algorithm).fit_transform(X)

# %%
df = timeit(benchmark_dense(), repeat=3).wall_time
# Out:
# 294it [13:26, 10.85s/it]

# %% [markdown]
# Below is the wall_time in seconds (faster solver is highlighted in green),

# %%
df['mean'].unstack().round(2).style.apply(highlight_best, axis=1)
# Out:
# <style  type="text/css" >
#     #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow0_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow1_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow1_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow2_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow3_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow4_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow5_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow6_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow7_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow8_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow9_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow10_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow11_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow12_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow13_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow14_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow15_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow16_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow17_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow18_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow18_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow19_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow19_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow20_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow21_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow22_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow23_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow24_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow25_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow26_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow27_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow28_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow29_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow30_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow31_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow32_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow33_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow34_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow35_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow36_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow37_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow38_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow39_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow40_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow41_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow42_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow43_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow44_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow45_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow46_col0 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow47_col1 {
#             background-color:  #206b3c80;
#         }    #T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow48_col0 {
#             background-color:  #206b3c80;
#         }</style><table id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25ef" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="index_name level0" >algorithm</th>        <th class="col_heading level0 col0" >lobpcg</th>        <th class="col_heading level0 col1" >randomized</th>    </tr>    <tr>        <th class="index_name level0" >n_components</th>        <th class="index_name level1" >n_samples</th>        <th class="index_name level2" >n_features</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25eflevel0_row0" class="row_heading level0 row0" rowspan=18>2</th>
#                         <th id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25eflevel1_row0" class="row_heading level1 row0" rowspan=4>5000</th>
#                         <th id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25eflevel2_row0" class="row_heading level2 row0" >50</th>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow0_col1" class="data row0 col1" >0.01</td>
#             </tr>
#             <tr>
#                                         <th id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25eflevel2_row1" class="row_heading level2 row1" >500</th>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow1_col0" class="data row1 col0" >0.03</td>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow1_col1" class="data row1 col1" >0.03</td>
#             </tr>
#             <tr>
#                                         <th id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25eflevel2_row2" class="row_heading level2 row2" >1000</th>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow2_col0" class="data row2 col0" >0.08</td>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow2_col1" class="data row2 col1" >0.07</td>
#             </tr>
#             <tr>
#                                         <th id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25eflevel2_row3" class="row_heading level2 row3" >5000</th>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow3_col0" class="data row3 col0" >0.39</td>
#                         <td id="T_5bdd3d78_62aa_11e9_bf2d_5bf4718a25efrow3_col1" class="data row3 c
